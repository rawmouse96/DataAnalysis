# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False

# %% [markdown]
# ### 1. Tips data

# %%
tips = sns.load_dataset('tips')
tips
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3

# %%
tips_day = tips.pivot_table('tip', 'day')
tips_size = tips.pivot_table('tip', 'size')

tips_day, tips_size
# Out:
# (           tip
#  day
#  Thur  2.771452
#  Fri   2.734737
#  Sat   2.993103
#  Sun   3.255132,
#             tip
#  size
#  1     1.437500
#  2     2.582308
#  3     3.393158
#  4     4.135405
#  5     4.028000
#  6     5.225000)

# %%
plt.bar(tips_day.index, tips_day.tip, width=0.4)
plt.title('요일별 팁의 비율')
plt.show()

# %%
plt.bar(tips_size.index, tips_size.tip, width=0.4)
plt.title('인원수별 팁의 비율')
plt.show()

# %% [markdown]
# ### 2. Anscombe 데이터

# %%
ans = sns.load_dataset('anscombe')
ans.head(5)
# Out:
#   dataset     x     y
# 0       I  10.0  8.04
# 1       I   8.0  6.95
# 2       I  13.0  7.58
# 3       I   9.0  8.81
# 4       I  11.0  8.33

# %%
ans1 = ans[ans['dataset'] == 'I']
ans2 = ans[ans['dataset'] == 'II']
ans3 = ans[ans['dataset'] == 'III']
ans4 = ans[ans['dataset'] == 'IV']
ans1
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68

# %%
x = np.linspace(4, 14)
x1 = np.linspace(4, 20)
y = 3 + 0.5*x1

# %%
plt.scatter(ans1.x, ans1.y)
plt.plot(x1, y, 'r')
plt.title('Anscombe quartet 1'), plt.grid()
plt.show()

plt.scatter(ans2.x, ans2.y)
plt.plot(x1, y, 'r')
plt.title('Anscombe quartet 2'), plt.grid()
plt.show()

plt.scatter(ans3.x, ans3.y)
plt.plot(x1, y, 'r')
plt.title('Anscombe quartet 3'), plt.grid()
plt.show()

plt.scatter(ans4.x, ans4.y)
plt.plot(x1, y, 'r')
plt.title('Anscombe quartet 4'), plt.grid()
plt.show()

# %% [markdown]
# ### 3. 서울시 구별 CCTV 댓수
