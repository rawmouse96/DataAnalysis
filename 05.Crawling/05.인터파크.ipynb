# %% [markdown]
# ### 인터파크 - 베스트셀러

# %%
import requests
import pandas as pd
from urllib.parse import quote
from bs4 import BeautifulSoup

# %%
# http://book.interpark.com/display/collectlist.do?_method=bestsellerHourNew&bookblockname=b_gnb&booklinkname=%BA%A3%BD%BA%C6%AE%C1%B8&bid1=w_bgnb&bid2=LiveRanking&bid3=main&bid4=001&utm_term=%EC%9D%B8%ED%84%B0%ED%8C%8C%ED%81%AC%EB%8F%84%EC%84%9C&gclid=EAIaIQobChMIi_zW8uzD_gIVUbSWCh3NCwbAEAAYASABEgI7LfD_BwE
url = 'http://book.interpark.com/display/collectlist.do?_method=BestsellerHourNew201605&bestTp=1&dispNo=028'
res = requests.get(url)
soup = BeautifulSoup(res.text, 'html.parser')

# %%
lis = soup.select('.rankBestContentList > ol > li')
lis
# Out:
# [<li>
#  <!-- listItem | singleType or setType :: start -->
#  <div class="listItem singleType">
#  <div class="cover">
#  <div class="coverImage">
#  <label>
#  <a href="/product/BookDisplay.do?_method=detail&amp;sc.shopNo=0000400000&amp;sc.prdNo=356522531&amp;sc.saNo=003003001&amp;bid1=Best_zone&amp;bid2=LiveRanking&amp;bid3=PRD&amp;bid4=001" target="_blank">
#  <span class="checkBox">
#  <input name="_KEY" type="checkbox" value="356522531"/>
#  </span>
#  <img alt="세이노의 가르침" src="http://bimage.interpark.com/goods_image/2/5/3/1/356522531s.jpg"/>
#  <i class="decoFront"></i>
#  </a>
#  </label>
#  </div>
#  <div class="coverOption">
#  <ul>
#  <li class="cart">
#  <a class="cartGo" href="#" value="356522531"><span>CART</span></a>
#  </li>
#  <li class="buy">
#  <a href="javascript:directOrd('356522531');"><span>BUY</span></a>
#  </li>
#  </ul>
#  </div>
#  <div class="rankNumber digit2">
#  <span class="rankBtn_ctrl rkNum_B01"></span>
#  </div>
#  </div>
#  <div class="itemIcon">
#  <span class="bestSeller">베스트셀러</span>
#  </div>
#  <a href="/product/BookDisplay.do?_method=detail&amp;sc.shopNo=0000400000&amp;sc.prdNo=356522531&amp;sc.saNo=003003001&amp;bid1=Best_zone&amp;bid2=LiveRanking&amp;bid3=PRD&amp;bid4=001" target="_blank">
#  <div class="itemName"><strong>세이노의 가르침 </strong></div>
#  <div class="itemMeta">
#  <span class="author">세이노</span>
#  <span class="company">데이원</span>
#  </div>
#  <div class="priceWrap">
#  <span class="price">
#  <em>6,480</em>
#  <span class="currency">원</span>
#  </span>
#  <span class="benefits">
#  <span>(</span>
#  <span class="discount">
#  <em>10%</em>
#  <span class="unit">할인</span>
#  </span>
#  <span class="save">
#  <em>5%</em>
#  <span class="unit">적립</span>
#  </span>
#  <span>)</span>
#  </span>
#  </div>
#  </a>
#  <div class="reviewStat">
#  <span class="title">평점</span>
#  <span class="starRateWrap">
#  <span class="starRate" style="width:99%">9.9</span>
#  </span>
#  <em class="rateNumber">9.9</em>
#  </div>
#  <div class="saleIndex">
#  <span class="title">판매지수</span>
#  <em class="indexNumber">256,409</em>
#  </div>
#  <div class="relatedEvent">
#  <ul>
#  <li>
#  <a href="http://book.interpark.com/book/genbookeventaction.do?_method=EventPlan&amp;sc.evtNo=242222" target="_blank">[기획] 카카오페이와 도서상품권 ...</a>
#  </li>
#  <li>
#  <a href="http://book.interpark.com/book/genbookeventaction.do?_method=EventPlan&amp;sc.evtNo=242643" target="_blank">[기획] 최초 한국 공연 &lt;식스 ...</a>
#  </li>
#  <li>
#  <a href="http://book.interpark.com/book/genbookeventaction.do?_method=EventPlan&amp;sc.evtNo=242639" target="_blank">[기획] 카카오페이 &amp; 도서상품권...</a>
#  </li>
#  </ul>
#  </div>
#  </div>
#  <!-- singleType or setType :: end -->
#  </li>,
#  <li>
#  <!-- listItem | singleType or setType :: start -->
#  <div class="listItem singleType">
#  <div class="cover">
#  <div class="coverImage">
#  <label>
#  <a href="/product/BookDisplay.do?_method=detail&amp;sc.shopNo=0000400000&amp;sc.prdNo=356714678&amp;sc.saNo=003003001&amp;bid1=Best_zone&amp;bid2=LiveRanking&amp;bid3=PRD&amp;bid4=001" target="_blank">
#  <span class="checkBox">
#  <input name="_KEY" type="checkbox" value="356714678"/>
#  </span>
#  <img alt="모든 삶은 흐른다" src="https://bimage.interpark.com/partner/goods_image/4/6/7/8/356714678s.jpg"/>
#  <i class="decoFront"></i>
#  </a>
#  </label>
#  </div>
#  <div class="coverOption">
#  <ul>
#  <li class="cart">
#  <a class="cartGo" href="#" value="356714678"><span>CART</span></a>
#  </li>
#  <li class="buy">
#  <a href="javascript:directOrd('356714678');"><span>BUY</span></a>
#  </li>
#  </ul>
#  </div>
#  <div class="rankNumber digit2">
#  <span class="rankBtn_ctrl rkNum_B02"></span>
#  </div>
#  </div>
#  <div class="itemIcon">
#  <span class="bestSeller">베스트셀러</span>
#  </div>
#  <a href="/product/BookDisplay.do?_method=detail&amp;sc.shopNo=0000400000&amp;sc.prdNo=356714678&amp;sc.saNo=003003001&amp;bid1=Best_zone&amp;bid2=LiveRanking&amp;bid3=PRD&amp;bid4=001" target="_blank">
#  <div class="itemName"><strong>모든 삶은 흐른다 </strong></div>
#  <div class="itemMeta">
#  <span class="author">로랑스 드빌레르/이주영 역</span>
#  <span class="company">피카(FIKA)</span>
#  </div>
#  <div class="priceWrap">
#  <span class="price">
#  <em>15,120</em>
#  <span class="currency">원</span>
#  </span>
#  <span class="benefits">
#  <span>(</span>
#  <span class="discount">
#  <em>10%</em>
#  <span class="unit">할인</span>
#  </span>
#  <span class="save">
#  <em>5%</em>
#  <span class="unit">적립</span>
#  </span>
#  <span>)</span>
#  </span>
#  </div>
#  </a>
#  <div class="reviewStat">
#  <span class="title">평점</span>
#  <span class="starRateWrap">
#  <span class="starRate" style="width:100%">10</span>
#  </span>
#  <em class="rateNumber">10</em>
#  </div>
#  <div class="saleIndex">
#  <span class="title">판매지수</span>
#  <em class="indexNumber">36,922</em>
#  </div>
#  <div class="relatedEvent">
#  <ul>
#  <li>
#  <a href="http://book.interpark.com/book/genbookeventaction.do?_method=EventPlan&amp;sc.evtNo=242643" target="_blank">[기획] 최초 한국 공연 &lt;식스 ...</a>
#  </li>
#  </ul>
#  </div>
#  </div>
#  <!-- singleType or setType :: end -->
#  </li>,
#  <li>
#  <!-- listItem | singleType or setType :: start -->
#  <div class="listItem singleType">
#  <div class="cover">
#  <div class="coverImage">
#  <label>
#  <a href="/product/BookDisplay.do?_method=detail&amp;sc.shopNo=0000400000&amp;sc.prdNo=356708752&amp;sc.saNo=003003001&amp;bid1=Best_zone&amp;bid2=LiveRanking&amp;bid3=PRD&amp;bid4=001" target="_blank">
#  <span class="checkBox">
#  <input name="_KEY" type="checkbox" value="356708752"/>
#  </span>
#  <img alt="사장학개론" src="https://bimage.interpark.com/partner/goods_image/8/7/5/2/356708752s.jpg"/>
#  <i class="decoFront"></i>
#  </a>
#  </label>
#  </div>
#  <div class="coverOption">
#  <ul>
#  <li class="cart">
#  <a class="cartGo" href="#" value="356708752"><span>CART</span></a>
#  </li>
#  <li class="buy">
#  <a href="javascript:directOrd('356708752');"><span>BUY</span></a>
#  </li>
#  </ul>
#  </div>
#  <div class="rankNumber digit2">
#  <span class="rankBtn_ctrl rkNum_B03"></span>
#  </div>
#  </div>
#  <div class="itemIcon">
#  <span class="bestSeller">베스트셀러</span>
#  </div>
#  <a href="/product/BookDisplay.do?_method=detail&amp;sc.shopNo=0000400000&amp;sc.prdNo=356708752&amp;sc.saNo=003003001&amp;bid1=Best_zone&amp;bid2=LiveRanking&amp;bid3=PRD&amp;bid4=001" target="_blank">
#  <div class="itemName"><strong>사장학개론 </strong></div>
#  <div class="itemMeta">
#  <span class="author">김승호</span>
#  <span class="company">스노우폭스북스</span>
#  </div>
#  <div class="priceWrap">
#  <span class="price">
#  <em>22,500</em>
#  <span class="currency">원</span>
#  </span>
#  <span class="benefits">
#  <span>(</span>
#  <span class="discount">
#  <em>10%</em>
#  <span class="unit">할인</span>
#  </span>
#  <span class="save">
#  <em>5%</em>
#  <span class="unit">적립</span>
#  </span>
#  <span>)</span>
#  </span>
#  </div>
#  </a>
#  <div class="reviewStat">
#  <span class="title">평점</span>
#  <span class="starRateWrap">
#  <span class="starRate" style="width:97%">9.7</span>
#  </span>
#  <em class="rateNumber">9.7</em>
#  </div>
#  <div class="saleIndex">
#  <span class="title">판매지수</span>
#  <em class="indexNumber">29,340</em>
#  </div>
#  <div class="relatedEvent">
#  <ul>
#  <li>
#  <a href="http://book.interpark.com/book/genbookeventaction.do?_method=EventPlan&amp;sc.evtNo=242643" target="_blank">[기획] 최초 한국 공연 &lt;식스 ...</a>
#  </li>
#  </ul>
#  </div>
#  </div>
#  <!-- singleType or setType :: end -->
#  </li>,
#  <li>
#  <!-- listItem | singleType or setType :: start -->
#  <div class="listItem singleType">
#  <div class="cover">
#  <div class="coverImage">
#  <label>
#  <a href="/product/BookDisplay.do?_method=detail&amp;sc.shopNo=0000400000&amp;sc.prdNo=355590667&amp;sc.saNo=003003001&amp;bid1=Best_zone&amp;bid2=LiveRanking&amp;bid3=PRD&amp;bid4=001" target="_blank">
#  <span class="checkBox">
#  <input name="_KEY" type="checkbox" value="355590667"/>
#  </span>
#  <img alt="건강과 다이어트를 동시에 잡는 7대 3의 법칙 채소·과일식" src="https://bimage.interpark.com/partner/goods_image/0/6/6/7/355590667s.jpg"/>
#  <i class="decoFront"></i>
#  </a>
#  </label>
#  </div>
#  <div class="coverOption">
#  <ul>
#  <li class="cart">
#  <a class="cartGo" href="#" value="355590667"><span>CART</span></a>
#  </li>
#  <li class="buy">
#  <a href="javascript:directOrd('355590667');"><span>BUY</span></a>
#  </li>
#  </ul>
#  </div>
#  <div class="rankNumber digit2">
#  <span class="rankBtn_ctrl rkNum_B04"></span>
#  </div>
#  </div>
#  <div class="itemIcon">
#  <span class="bestSeller">베스트셀러</span>
#  <span class="steadySeller">스테디셀러</span>
#  </div>
#  <a href="/product/BookDisplay.do?_method=detail&amp;sc.shopNo=0000400000&amp;sc.prdNo=355590667&amp;sc.saNo=003003001&amp;bid1=Best_zone&amp;bid2=LiveRanking&amp;bid3=PRD&amp;bid4=001" target="_blank">
#  <div class="itemName"><strong>건강과 다이어트를 동시에 잡는 7대 3의 법칙 채소·과일식 </strong></div>
#  <div class="itemMeta">
#  <span class="author">조승우</span>
#  <span class="company">바이북스</span>
#  </div>
#  <div class="priceWrap">
#  <span class="price">
#  <em>17,100</em>
#  <span class="currency">원</span>
#  </span>
#  <span class="benefits">
#  <span>(</span>
#  <span class="discount">
#  <em>10%</em>
#  <span class="unit">할인</span>
#  </span>
#  <span class="save">
#  <em>5%</em>
#  <span class="unit">적립</span>
#  </span>
#  <span>)</span>
#  </span>
#  </div>
#  </a>
#  <div class="reviewStat">
#  <span class="title">평점</span>
#  <span class="starRateWrap">
#  <span class="starRate" style="width:96%">9.6</span>
#  </span>
#  <em class="rateNumber">9.6</em>
#  </div>
#  <div class="saleIndex">
#  <span class="title">판매지수</span>
#  <em class="indexNumber">28,948</em>
#  </div>
#  <div class="relatedEvent">
#  <ul>
#  <li>
#  <a href="http://book.interpark.com/book/genbookeventaction.do?_method=EventPlan&amp;sc.evtNo=242643" target="_blank">[기획] 최초 한국 공연 &lt;식스 ...</a>
#  </li>
#  </ul>
#  </div>
#  </div>
#  <!-- singleType or setType :: end -->
#  </li>,
#  <li>
#  <!-- listItem | singleType or setType :: start -->
#  <div class="listItem singleType">
#  <div class="cover">
#  <div class="coverImage">
#  <label>
#  <a href="/product/BookDisplay.do?_method=detail&amp;sc.shopNo=0000400000&amp;sc.prdNo=356728076&amp;sc.saNo=003003001&amp;bid1=Best_zone&amp;bid2=LiveRanking&amp;bid3=PRD&amp;bid4=001" target="_blank">
#  <span class="checkBox">
#  <input name="_KEY" type="checkbox" value="356728076"/>
#  </span>
#  <img alt="흔한남매 13" src="https://bimage.interpark.com/partner/goods_image/8/0/7/6/356728076s.jpg"/>
#  <i class="decoFront"></i>
#  </a>
#  </label>
#  </div>
#  <div class="coverOption">
#  <ul>
#  <li class="cart">
#  <a class="cartGo" href="#" value="356728076"><span>CART</span></a>
#  </li>
#  <li class="buy">
#  <a href="javascript:directOrd('356728076');"><span>BUY</span></a>
#  </li>
#  </ul>
#  </div>
#  <div class="rankNumber digit2">
#  <span class="rankBtn_ctrl rkNum_B05"></span>
#  </div>
#  </div>
#  <div class="itemIcon">
#  <span class="bestSeller">베스트셀러</span>
#  </div>
#  <a href="/product/BookDisplay.do?_method=detail&amp;sc.shopNo=0000400000&amp;sc.prdNo=356728076&amp;sc.saNo=003003001&amp;bid1=Best_zone&amp;bid2=LiveRanking&amp;bid3=PRD&amp;bid4=001" target="_blank">
#  <div class="itemName"><strong>흔한남매 13 </strong></div>
#  <div class="itemMeta">
#  <span class="author">흔한남매, 백난도/유난희 그림/흔한컴퍼니 감수</span>
#  <span class="company">미래엔아이세움</span>
#  </div>
#  <div class="priceWrap">
#  <span class="price">
#  <em>13,050</em>
#  <span class="currency">원</span>
#  </span>
#  <span class="benefits">
#  <span>(</span>
#  <span class="discount">
#  <em>10%</em>
#  <span class="unit">할인</span>
#  </span>
#  <span class="save">
#  <em>5%</em>
#  <span class="unit">적립</span>
#  </span>
#  <span>)</span>
#  </span>
#  </div>
#  </a>
#  <div class="reviewStat">
#  <span class="title">평점</span>
#  <span class="starRateWrap">
#  <span class="starRate" style="width:100%">10</span>
#  </span>
#  <em class="rateNumber">10</em>
#  </div>
#  <div class="saleIndex">
#  <span class="title">판매지수</span>
#  <em class="indexNumber">26,826</em>
#  </div>
#  <div class="relatedEvent">
#  <ul>
#  <li>
#  <a href="http://book.interpark.com/book/genbookeventaction.do?_method=EventPlan&amp;sc.evtNo=242789" target="_blank">[기획] 슬기롭게 세상을 만들어가...</a>
#  </li>
#  <li>
#  <a href="http://book.interpark.com/book/genbookeventaction.do?_method=EventPlan&amp;sc.evtNo=242643" target="_blank">[기획] 최초 한국 공연 &lt;식스 ...</a>
#  </li>
#  </ul>
#  </div>
#  </div>
#  <!-- singleType or setType :: end -->
#  </li>,
#  <li>
#  <!-- listItem | singleType or setType :: start -->
#  <div class="listItem singleType">
#  <div class="cover">
#  <div class="coverImage">
#  <label>
#  <a href="/product/BookDisplay.do?_method=detail&amp;sc.shopNo=0000400000&amp;sc.prdNo=356710466&amp;sc.saNo=003003001&amp;bid1=Best_zone&amp;bid2=LiveRanking&amp;bid3=PRD&amp;bid4=001" target="_blank">
#  <span class="checkBox">
#  <input name="_KEY" type="checkbox" value="356710466"/>
#  </span>
#  <img alt="장하준의 경제학 레시피" src="http://bimage.interpark.com/goods_image/0/4/6/6/356710466s.jpg"/>
#  <i class="decoFront"></i>
#  </a>
#  </label>
#  </div>
#  <div class="coverOption">
#  <ul>
#  <li class="cart">
#  <a class="cartGo" href="#" value="356710466"><span>CART</span></a>
#  </li>
#  <li class="buy">
#  <a href="javascript:directOrd('356710466');"><span>BUY</span></a>
#  </li>
#  </ul>
#  </div>
#  <div class="rankNumber digit2">
#  <span class="rankBtn_ctrl rkNum_B05"></span>
#  </div>
#  </div>
#  <div class="itemIcon">
#  <span class="bestSeller">베스트셀러</span>
#  </div>
#  <a href="/product/BookDisplay.do?_method=detail&amp;sc.shopNo=0000400000&amp;sc.prdNo=356710466&amp;sc.saNo=003003001&amp;bid1=Best_zone&amp;bid2=LiveRanking&amp;bid3=PRD&amp;bid4=001" target="_blank">
#  <div class="itemName"><strong>장하준의 경제학 레시피 </strong></div>
#  <div class="itemMeta">
#  <span class="author">장하준</span>
#  <span class="company">부키</span>
#  </div>
#  <div class="priceWrap">
#  <span class="price">
#  <em>16,200</em>
#  <span class="currency">원</span>
#  </span>
#  <span class="benefits">
#  <span>(</span>
#  <span class="discount">
#  <em>10%</em>
#  <span class="unit">할인</span>
#  </span>
#  <span class="save">
#  <em>5%</em>
#  <span class="unit">적립</span>
#  </span>
#  <span>)</span>
#  </span>
#  </div>
#  </a>
#  <div class="reviewStat">
#  <span class="title">평점</span>
#  <span class="starRateWrap">
#  <span class="starRate" style="width:99%">9.9</span>
#  </span>
#  <em class="rateNumber">9.9</em>
#  </div>
#  <div class="saleIndex">
#  <span class="title">판매지수</span>
#  <em class="indexNumber">50,248</em>
#  </div>
#  <div class="relatedEvent">
#  <ul>
#  <li>
#  <a href="http://book.interpark.com/book/genbookeventaction.do?_method=EventPlan&amp;sc.evtNo=242222" target="_blank">[기획] 카카오페이와 도서상품권 ...</a>
#  </li>
#  <li>
#  <a href="http://book.interpark.com/book/genbookeventaction.do?_method=EventPlan&amp;sc.evtNo=242643" target="_blank">[기획] 최초 한국 공연 &lt;식스 ...</a>
#  </li>
#  <li>
#  <a href="http://book.interpark.com/book/genbookeventaction.do?_method=EventPlan&amp;sc.evtNo=242639" target="_blank">[기획] 카카오페이 &amp; 도서상품권...</a>
#  </li>
#  </ul>
#  </div>
#  </div>
#  <!-- singleType or setType :: end -->
#  </li>,
#  <li>
#  <!-- listItem | singleType or setType :: start -->
#  <div class="listItem singleType">
#  <div class="cover">
#  <div class="coverImage">
#  <label>
#  <a href="/product/BookDisplay.do?_method=detail&amp;sc.shopNo=0000400000&amp;sc.prdNo=2523927&amp;sc.saNo=003003001&amp;bid1=Best_zone&amp;bid2=LiveRanking&amp;bid3=PRD&amp;bid4=001" target="_blank">
#  <span class="checkBox">
#  <input name="_KEY" type="checkbox" value="2523927"/>
#  </span>
#  <img alt="고래" src="https://bimage.interpark.com/partner/goods_image/3/9/2/7/2523927s.jpg"/>
#  <i class="decoFront"></i>
#  </a>
#  </label>
#  </div>
#  <div class="coverOption">
#  <ul>
#  <li class="cart">
#  <a class="cartGo" href="#" value="2523927"><span>CART</span></a>
#  </li>
#  <li class="buy">
#  <a href="javascript:directOrd('2523927');"><span>BUY</span></a>
#  </li>
#  </ul>
#  </div>
#  <div class="rankNumber digit2">
#  <span class="rankBtn_ctrl rkNum_B05"></span>
#  </div>
#  </div>
#  <div class="itemIcon">
#  <span class="bestSeller">베스트셀러</span>
#  </div>
#  <a href="/product/BookDisplay.do?_method=detail&amp;sc.shopNo=0000400000&amp;sc.prdNo=2523927&amp;sc.saNo=003003001&amp;bid1=Best_zone&amp;bid2=LiveRanking&amp;bid3=PRD&amp;bid4=001" target="_blank">
#  <div class="itemName"><strong>고래 </strong></div>
#  <div class="itemMeta">
#  <span class="author">천명관</span>
#  <span class="company">문학동네</span>
#  </div>
#  <div class="priceWrap">
#  <span class="price">
#  <em>13,500</em>
#  <span class="currency">원</span>
#  </span>
#  <span class="benefits">
#  <span>(</span>
#  <span class="discount">
#  <em>10%</em>
#  <span class="unit">할인</span>
#  </span>
#  <span class="save">
#  <em>5%</em>
#  <span class="unit">적립</span>
#  </span>
#  <span>)</span>
#  </span>
#  </div>
#  </a>
#  <div class="reviewStat">
#  <span class="title">평점</span>
#  <span class="starRateWrap">
#  <span class="starRate" style="width:92%">9.2</span>
#  </span>
#  <em class="rateNumber">9.2</em>
#  </div>
#  <div class="saleIndex">
#  <span class="title">판매지수</span>
#  <em class="indexNumber">7,555</em>
#  </div>
#  <div class="relatedEvent">
#  <ul>
#  <li>
#  <a href="http://book.interpark.com/book/genbookeventaction.do?_method=EventPlan&amp;sc.evtNo=242643" target="_blank">[기획] 최초 한국 공연 &lt;식스 ...</a>
#  </li>
#  </ul>
#  </div>
#  </div>
#  <!-- singleType or setType :: end -->
#  </li>,
#  <li>
#  <!-- listItem | singleType or setType :: start -->
#  <div class="listItem singleType">
#  <div class="cover">
#  <div class="coverImage">
#  <label>
#  <a href="/product/BookDisplay.do?_method=detail&amp;sc.shopNo=0000400000&amp;sc.prdNo=279599379&amp;sc.saNo=003003001&amp;bid1=Best_zone&amp;bid2=LiveRanking&amp;bid3=PRD&amp;bid4=001" target="_blank">
#  <span class="checkBox">
#  <input name="_KEY" type="checkbox" value="279599379"/>
#  </span>
#  <img alt="부자 아빠 가난한 아빠 1(20주년 특별 기념판)" src="https://bimage.interpark.com/partner/goods_image/9/3/7/9/279599379s.jpg"/>
#  <i class="decoFront"></i>
#  </a>
#  </label>
#  </div>
#  <div class="coverOption">
#  <ul>
#  <li class="cart">
#  <a class="cartGo" href="#" value="279599379"><span>CART</span></a>
#  </li>
#  <li class="buy">
#  <a href="javascript:directOrd('279599379');"><span>BUY</span></a>
#  </li>
#  </ul>
#  </div>
#  <div class="rankNumber digit2">
#  <span class="rankBtn_ctrl rkNum_B08"></span>
#  </div>
#  </div>
#  <div class="itemIcon">
#  <span class="bestSeller">베스트셀러</span>
#  <span class="steadySeller">스테디셀러</span>
#  </div>
#  <a href="/product/BookDisplay.do?_method=detail&amp;sc.shopNo=0000400000&amp;sc.prdNo=279599379&amp;sc.saNo=003003001&amp;bid1=Best_zone&amp;bid2=LiveRanking&amp;bid3=PRD&amp;bid4=001" target="_blank">
#  <div class="itemName"><strong>부자 아빠 가난한 아빠 1(20주년 특별 기념판) </strong></div>
#  <div class="itemMeta">
#  <span class="author">로버트 기요사키/안진환 역</span>
#  <span class="company">민음인</span>
#  </div>
#  <div class="priceWrap">
#  <span class="price">
#  <em>15,300</em>
#  <span class="currency">원</span>
#  </span>
#  <span class="benefits">
#  <span>(</span>
#  <span class="discount">
#  <em>10%</em>
#  <span class="unit">할인</span>
#  </span>
#  <span class="save">
#  <em>5%</em>
#  <span class="unit">적립</span>
#  </span>
#  <span>)</span>
#  </span>
#  </div>
#  </a>
#  <div class="reviewStat">
#  <span class="title">평점</span>
#  <span class="starRateWrap">
#  <span class="starRate" style="width:98%">9.8</span>
#  </span>
#  <em class="rateNumber">9.8</em>
#  </div>
#  <div class="saleIndex">
#  <span class="title">판매지수</span>
#  <em class="indexNumber">12,196</em>
#  </div>
#  <div class="relatedEvent">
#  <ul>
#  </ul>
#  </div>
#  </div>
#  <!-- singleType or setType :: end -->
#  </li>,
#  <li>
#  <!-- listItem | singleType or setType :: start -->
#  <div class="listItem singleType">
#  <div class="cover">
#  <div class="coverImage">
#  <label>
#  <a href="/product/BookDisplay.do?_method=detail&amp;sc.shopNo=0000400000&amp;sc.prdNo=356730966&amp;sc.saNo=003003001&amp;bid1=Best_zone&amp;bid2=LiveRanking&amp;bid3=PRD&amp;bid4=001" target="_blank">
#  <span class="checkBox">
#  <input name="_KEY" type="checkbox" value="356730966"/>
#  </span>
#  <img alt="마법천자문 58: 온 정성과 힘을 다한다! 최선" src="https://bimage.interpark.com/partner/goods_image/0/9/6/6/356730966s.jpg"/>
#  <i class="decoFront"></i>
#  </a>
#  </label>
#  </div>
#  <div class="coverOption">
#  <ul>
#  <li class="cart">
#  <a class="cartGo" href="#" value="356730966"><span>CART</span></a>
#  </li>
#  <li class="buy">
#  <a href="javascript:directOrd('356730966');"><span>BUY</span></a>
#  </li>
#  </ul>
#  </div>
#  <div class="rankNumber digit2">
#  <span class="rankBtn_ctrl rkNum_B09"></span>
#  </div>
#  </div>
#  <div class="itemIcon">
#  <span class="bestSeller">베스트셀러</span>
#  </div>
#  <a href="/product/BookDisplay.do?_method=detail&amp;sc.shopNo=0000400000&amp;sc.prdNo=356730966&amp;sc.saNo=003003001&amp;bid1=Best_zone&amp;bid2=LiveRanking&amp;bid3=PRD&amp;bid4=001" target="_blank">
#  <div class="itemName"><strong>마법천자문 58: 온 정성과 힘을 다한다! 최선 </strong></div>
#  <div class="itemMeta">
#  <span class="author">유대영/정수영 그림/강용철 감수</span>
#  <span class="company">아울북</span>
#  </div>
#  <div class="priceWrap">
#  <span class="price">
#  <em>12,600</em>
#  <span class="currency">원</span>
#  </span>
#  <span class="benefits">
#  <span>(</span>
#  <span class="discount">
#  <em>10%</em>
#  <span class="unit">할인</span>
#  </span>
#  <span class="save">
#  <em>5%</em>
#  <span class="unit">적립</span>
#  </span>
#  <span>)</span>
#  </span>
#  </div>
#  </a>
#  <div class="reviewStat">
#  <span class="title">평점</span>
#  <span class="starRateWrap">
#  <span class="starRate" style="width:0%"></span>
#  </span>
#  <em class="rateNumber"></em>
#  </div>
#  <div class="saleIndex">
#  <span class="title">판매지수</span>
#  <em class="indexNumber">4,318</em>
#  </div>
#  <div class="relatedEvent">
#  <ul>
#  <li>
#  <a href="http://book.interpark.com/book/genbookeventaction.do?_method=EventPlan&amp;sc.evtNo=242789" target="_blank">[기획] 슬기롭게 세상을 만들어가...</a>
#  </li>
#  </ul>
#  </div>
#  </div>
#  <!-- singleType or setType :: end -->
#  </li>,
#  <li>
#  <!-- listItem | singleType or setType :: start -->
#  <div class="listItem singleType">
#  <div class="cover">
#  <div class="coverImage">
#  <label>
#  <a href="/product/BookDisplay.do?_method=detail&amp;sc.shopNo=0000400000&amp;sc.prdNo=356726606&amp;sc.saNo=003003001&amp;bid1=Best_zone&amp;bid2=LiveRanking&amp;bid3=PRD&amp;bid4=001" target="_blank">
#  <span class="checkBox">
#  <input name="_KEY" type="checkbox" value="356726606"/>
#  </span>
#  <img alt="나의 돈 많은 고등학교 친구" src="https://bimage.interpark.com/partner/goods_image/6/6/0/6/356726606s.jpg"/>
#  <i class="decoFront"></i>
#  </a>
#  </label>
#  </div>
#  <div class="coverOption">
#  <ul>
#  <li class="cart">
#  <a class="cartGo" href="#" value="356726606"><span>CART</span></a>
#  </li>
#  <li class="buy">
#  <a href="javascript:directOrd('356726606');"><span>BUY</span></a>
#  </li>
#  </ul>
#  </div>
#  <div class="rankNumber digit2">
#  <span class="rankBtn_ctrl rkNum_B09"></span>
#  </div>
#  </div>
#  <div class="itemIcon">
#  <span class="bestSeller">베스트셀러</span>
#  </div>
#  <a href="/product/BookDisplay.do?_method=detail&amp;sc.shopNo=0000400000&amp;sc.prdNo=356726606&amp;sc.saNo=003003001&amp;bid1=Best_zone&amp;bid2=LiveRanking&amp;bid3=PRD&amp;bid4=001" target="_blank">
#  <div class="itemName"><strong>나의 돈 많은 고등학교 친구 </strong></div>
#  <div class="itemMeta">
#  <span class="author">송희구</span>
#  <span class="company">서삼독</span>
#  </div>
#  <div class="priceWrap">
#  <span class="price">
#  <em>16,200</em>
#  <span class="currency">원</span>
#  </span>
#  <span class="benefits">
#  <span>(</span>
#  <span class="discount">
#  <em>10%</em>
#  <span class="unit">할인</span>
#  </span>
#  <span class="save">
#  <em>5%</em>
#  <span class="unit">적립</span>
#  </span>
#  <span>)</span>
#  </span>
#  </div>
#  </a>
#  <div class="reviewStat">
#  <span class="title">평점</span>
#  <span class="starRateWrap">
#  <span class="starRate" style="width:100%">10</span>
#  </span>
#  <em class="rateNumber">10</em>
#  </div>
#  <div class="saleIndex">
#  <span class="title">판매지수</span>
#  <em class="indexNumber">19,655</em>
#  </div>
#  <div class="relatedEvent">
#  <ul>
#  <li>
#  <a href="http://book.interpark.com/book/genbookeventaction.do?_method=EventPlan&amp;sc.evtNo=242643" target="_blank">[기획] 최초 한국 공연 &lt;식스 ...</a>
#  </li>
#  </ul>
#  </div>
#  </div>
#  <!-- singleType or setType :: end -->
#  </li>,
#  <li>
#  <!-- listItem | singleType or setType :: start -->
#  <div class="listItem singleType">
#  <div class="cover">
#  <div class="coverImage">
#  <label>
#  <a href="/product/BookDisplay.do?_method=detail&amp;sc.shopNo=0000400000&amp;sc.prdNo=356714453&amp;sc.saNo=003003001&amp;bid1=Best_zone&amp;bid2=LiveRanking&amp;bid3=PRD&amp;bid4=001" target="_blank">
#  <span class="checkBox">
#  <input name="_KEY" type="checkbox" value="356714453"/>
#  </span>
#  <img alt="요괴어사" src="http://bimage.interpark.com/goods_image/4/4/5/3/356714453s.jpg"/>
#  <i class="decoFront"></i>
#  </a>
#  </label>
#  </div>
#  <div class="coverOption">
#  <ul>
#  <li class="cart">
#  <a class="cartGo" href="#" value="356714453"><span>CART</span></a>
#  </li>
#  <li class="buy">
#  <a href="javascript:directOrd('356714453');"><span>BUY</span></a>
#  </li>
#  </ul>
#  </div>
#  <div class="rankNumber digit2">
#  <span class="rankBtn_ctrl rkNum_B09"></span>
#  </div>
#  </div>
#  <div class="itemIcon">
#  </div>
#  <a href="/product/BookDisplay.do?_method=detail&amp;sc.shopNo=0000400000&amp;sc.prdNo=356714453&amp;sc.saNo=003003001&amp;bid1=Best_zone&amp;bid2=LiveRanking&amp;bid3=PRD&amp;bid4=001" target="_blank">
#  <div class="itemName"><strong>요괴어사 </strong></div>
#  <div class="itemMeta">
#  <span class="author">설민석, 원더스</span>
#  <span class="company">단꿈아이</span>
#  </div>
#  <div class="priceWrap">
#  <span class="price">
#  <em>16,200</em>
#  <span class="currency">원</span>
#  </span>
#  <span class="benefits">
#  <span>(</span>
#  <span class="discount">
#  <em>10%</em>
#  <span class="unit">할인</span>
#  </span>
#  <span class="save">
#  <em>5%</em>
#  <span class="unit">적립</span>
#  </span>
#  <span>)</span>
#  </span>
#  </div>
#  </a>
#  <div class="reviewStat">
#  <span class="title">평점</span>
#  <span class="starRateWrap">
#  <span class="starRate" style="width:99%">9.9</span>
#  </span>
#  <em class="rateNumber">9.9</em>
#  </div>
#  <div class="saleIndex">
#  <span class="title">판매지수</span>
#  <em class="indexNumber">536</em>
#  </div>
#  <div class="relatedEvent">
#  <ul>
#  </ul>
#  </div>
#  </div>
#  <!-- singleType or setType :: end -->
#  </li>,
#  <li>
#  <!-- listItem | singleType or setType :: start -->
#  <div class="listItem singleType">
#  <div class="cover">
#  <div class="coverImage">
#  <label>
#  <a href="/product/BookDisplay.do?_method=detail&amp;sc.shopNo=0000400000&amp;sc.prdNo=356726995&amp;sc.saNo=003003001&amp;bid1=Best_zone&amp;bid2=LiveRanking&amp;bid3=PRD&amp;bid4=001" target="_blank">
#  <span class="checkBox">
#  <input name="_KEY" type="checkbox" value="356726995"/>
#  </span>
#  <img alt="처음 배우는 주식 차트" src="https://bimage.interpark.com/partner/goods_image/6/9/9/5/356726995s.jpg"/>
#  <i class="decoFront"></i>
#  </a>
#  </label>
#  </div>
#  <div class="coverOption">
#  <ul>
#  <li class="cart">
#  <a class="cartGo" href="#" value="356726995"><span>CART</span></a>
#  </li>
#  <li class="buy">
#  <a href="javascript:directOrd('356726995');"><span>BUY</span></a>
#  </li>
#  </ul>
#  </div>
#  <div class="rankNumber digit2">
#  <span class="rankBtn_ctrl rkNum_B09"></span>
#  </div>
#  </div>
#  <div class="itemIcon">
#  <span class="bestSeller">베스트셀러</span>
#  </div>
#  <a href="/product/BookDisplay.do?_method=detail&amp;sc.shopNo=0000400000&amp;sc.prdNo=356726995&amp;sc.saNo=003003001&amp;bid1=Best_zone&amp;bid2=LiveRanking&amp;bid3=PRD&amp;bid4=001" target="_blank">
#  <div class="itemName"><strong>처음 배우는 주식 차트 </strong></div>
#  <div class="itemMeta">
#  <span class="author">친절한 재승씨</span>
#  <span class="company">알에이치코리아</span>
#  </div>
#  <div class="priceWrap">
#  <span class="price">
#  <em>34,200</em>
#  <span class="currency">원</span>
#  </span>
#  <span class="benefits">
#  <span>(</span>
#  <span class="discount">
#  <em>10%</em>
#  <span class="unit">할인</span>
#  </span>
#  <span class="save">
#  <em>5%</em>
#  <span class="unit">적립</span>
#  </span>
#  <span>)</span>
#  </span>
#  </div>
#  </a>
#  <div class="reviewStat">
#  <span class="title">평점</span>
#  <span class="starRateWrap">
#  <span class="starRate" style="width:100%">10</span>
#  </span>
#  <em class="rateNumber">10</em>
#  </div>
#  <div class="saleIndex">
#  <span class="title">판매지수</span>
#  <em class="indexNumber">3,910</em>
#  </div>
#  <div class="relatedEvent">
#  <ul>
#  <li>
#  <a href="http://book.interpark.com/book/genbookeventaction.do?_method=EventPlan&amp;sc.evtNo=242643" target="_blank">[기획] 최초 한국 공연 &lt;식스 ...</a>
#  </li>
#  </ul>
#  </div>
#  </div>
#  <!-- singleType or setType :: end -->
#  </li>,
#  <li>
#  <!-- listItem | singleType or setType :: start -->
#  <div class="listItem singleType">
#  <div class="cover">
#  <div class="coverImage">
#  <label>
#  <a href="/product/BookDisplay.do?_method=detail&amp;sc.shopNo=0000400000&amp;sc.prdNo=356729234&amp;sc.saNo=003003001&amp;bid1=Best_zone&amp;bid2=LiveRanking&amp;bid3=PRD&amp;bid4=001" target="_blank">
#  <span class="checkBox">
#  <input name="_KEY" type="checkbox" value="356729234"/>
#  </span>
#  <img alt="호퍼 A-Z" src="https://bimage.interpark.com/partner/goods_image/9/2/3/4/356729234s.jpg"/>
#  <i class="decoFront"></i>
#  </a>
#  </label>
#  </div>
#  <div class="coverOption">
#  <ul>
#  <li class="cart">
#  <a class="cartGo" href="#" value="356729234"><span>CART</span></a>
#  </li>
#  <li class="buy">
#  <a href="javascript:directOrd('356729234');"><span>BUY</span></a>
#  </li>
#  </ul>
#  </div>
#  <div class="rankNumber digit2">
#  <span class="rankBtn_ctrl rkNum_B09"></span>
#  </div>
#  </div>
#  <div class="itemIcon">
#  </div>
#  <a href="/product/BookDisplay.do?_method=detail&amp;sc.shopNo=0000400000&amp;sc.prdNo=356729234&amp;sc.saNo=003003001&amp;bid1=Best_zone&amp;bid2=LiveRanking&amp;bid3=PRD&amp;bid4=001" target="_blank">
#  <div class="itemName"><strong>호퍼 A-Z </strong></div>
#  <div class="itemMeta">
#  <span class="author">얼프 퀴스터/박상미 역</span>
#  <span class="company">한길사</span>
#  </div>
#  <div class="priceWrap">
#  <span class="price">
#  <em>19,800</em>
#  <span class="currency">원</span>
#  </span>
#  <span class="benefits">
#  <span>(</span>
#  <span class="discount">
#  <em>10%</em>
#  <span class="unit">할인</span>
#  </span>
#  <span class="save">
#  <em>5%</em>
#  <span class="unit">적립</span>
#  </span>
#  <span>)</span>
#  </span>
#  </div>
#  </a>
#  <div class="reviewStat">
#  <span class="title">평점</span>
#  <span class="starRateWrap">
#  <span class="starRate" style="width:97%">9.7</span>
#  </span>
#  <em class="rateNumber">9.7</em>
#  </div>
#  <div class="saleIndex">
#  <span class="title">판매지수</span>
#  <em class="indexNumber">824</em>
#  </div>
#  <div class="relatedEvent">
#  <ul>
#  </ul>
#  </div>
#  </div>
#  <!-- singleType or setType :: end -->
#  </li>,
#  <li>
#  <!-- listItem | singleType or setType :: start -->
#  <div class="listItem singleType">
#  <div class="cover">
#  <div class="coverImage">
#  <label>
#  <a href="/product/BookDisplay.do?_method=detail&amp;sc.shopNo=0000400000&amp;sc.prdNo=356730227&amp;sc.saNo=003003001&amp;bid1=Best_zone&amp;bid2=LiveRanking&amp;bid3=PRD&amp;bid4=001" target="_blank">
#  <span class="checkBox">
#  <input name="_KEY" type="checkbox" value="356730227"/>
#  </span>
#  <img alt="비트코인, 그리고 달러의 지정학" src="https://bimage.interpark.com/partner/goods_image/0/2/2/7/356730227s.jpg"/>
#  <i class="decoFront"></i>
#  </a>
#  </label>
#  </div>
#  <div class="coverOption">
#  <ul>
#  <li class="cart">
#  <a class="cartGo" href="#" value="356730227"><span>CART</span></a>
#  </li>
#  <li class="buy">
#  <a href="javascript:directOrd('356730227');"><span>BUY</span></a>
#  </li>
#  </ul>
#  </div>
#  <div class="rankNumber digit2">
#  <span class="rankBtn_ctrl rkNum_B09"></span>
#  </div>
#  </div>
#  <div class="itemIcon">
#  <span class="bestSeller">베스트셀러</span>
#  </div>
#  <a href="/product/BookDisplay.do?_method=detail&amp;sc.shopNo=0000400000&amp;sc.prdNo=356730227&amp;sc.saNo=003003001&amp;bid1=Best_zone&amp;bid2=LiveRanking&amp;bid3=PRD&amp;bid4=001" target="_blank">
#  <div class="itemName"><strong>비트코인, 그리고 달러의 지정학 </strong></div>
#  <div class="itemMeta">
#  <span class="author">오태민</span>
#  <span class="company">거인의정원</span>
#  </div>
#  <div class="priceWrap">
#  <span class="price">
#  <em>49,500</em>
#  <span class="currency">원</span>
#  </span>
#  <span class="benefits">
#  <span>(</span>
#  <span class="discount">
#  <em>10%</em>
#  <span class="unit">할인</span>
#  </span>
#  <span class="save">
#  <em>5%</em>
#  <span class="unit">적립</span>
#  </span>
#  <span>)</span>
#  </span>
#  </div>
#  </a>
#  <div class="reviewStat">
#  <span class="title">평점</span>
#  <span class="starRateWrap">
#  <span class="starRate" style="width:0%"></span>
#  </span>
#  <em class="rateNumber"></em>
#  </div>
#  <div class="saleIndex">
#  <span class="title">판매지수</span>
#  <em class="indexNumber">1,572</em>
#  </div>
#  <div class="relatedEvent">
#  <ul>
#  </ul>
#  </div>
#  </div>
#  <!-- singleType or setType :: end -->
#  </li>,
#  <li>
#  <!-- listItem | singleType or setType :: start -->
#  <div class="listItem singleType">
#  <div class="cover">
#  <div class="coverImage">
#  <label>
#  <a href="/product/BookDisplay.do?_method=detail&amp;sc.shopNo=0000400000&amp;sc.prdNo=355855624&amp;sc.saNo=003003001&amp;bid1=Best_zone&amp;bid2=LiveRanking&amp;bid3=PRD&amp;bid4=001" target="_blank">
#  <span class="checkBox">
#  <input name="_KEY" type="checkbox" value="355855624"/>
#  </span>
#  <img alt="만일 내가 인생을 다시 산다면(30만 부 기념 리커버 에디션)" src="http://bimage.interpark.com/goods_image/5/6/2/4/355855624s.jpg"/>
#  <i class="decoFront"></i>
#  </a>
#  </label>
#  </div>
#  <div class="coverOption">
#  <ul>
#  <li class="cart">
#  <a class="cartGo" href="#" value="355855624"><span>CART</span></a>
#  </li>
#  <li class="buy">
#  <a href="javascript:directOrd('355855624');"><span>BUY</span></a>
#  </li>
#  </ul>
#  </div>
#  <div class="rankNumber digit2">
#  <span class="rankBtn_ctrl rkNum_B09"></span>
#  </div>
#  </div>
#  <div class="itemIcon">
#  <span class="bestSeller">베스트셀러</span>
#  </div>
#  <a href="/product/BookDisplay.do?_method=detail&amp;sc.shopNo=0000400000&amp;sc.prdNo=355855624&amp;sc.saNo=003003001&amp;bid1=Best_zone&amp;bid2=LiveRanking&amp;bid3=PRD&amp;bid4=001" target="_blank">
#  <div class="itemName"><strong>만일 내가 인생을 다시 산다면(30만 부 기념 리커버 에디션) </strong></div>
#  <div class="itemMeta">
#  <span class="author">김혜남</span>
#  <span class="company">메이븐</span>
#  </div>
#  <div class="priceWrap">
#  <span class="price">
#  <em>15,480</em>
#  <span class="currency">원</span>
#  </span>
#  <span class="benefits">
#  <span>(</span>
#  <span class="discount">
#  <em>10%</em>
#  <span class="unit">할인</span>
#  </span>
#  <span class="save">
#  <em>5%</em>
#  <span class="unit">적립</span>
#  </span>
#  <span>)</span>
#  </span>
#  </div>
#  </a>
#  <div class="reviewStat">
#  <span class="title">평점</span>
#  <span class="starRateWrap">
#  <span class="starRate" style="width:87%">8.7</span>
#  </span>
#  <em class="rateNumber">8.7</em>
#  </div>
#  <div class="saleIndex">
#  <span class="title">판매지수</span>
#  <em class="indexNumber">95,141</em>
#  </div>
#  <div class="relatedEvent">
#  <ul>
#  <li>
#  <a href="http://book.interpark.com/book/genbookeventaction.do?_method=EventPlan&amp;sc.evtNo=242222" target="_blank">[기획] 카카오페이와 도서상품권 ...</a>
#  </li>
#  <li>
#  <a href="http://book.interpark.com/book/genbookeventaction.do?_method=EventPlan&amp;sc.evtNo=242643" target="_blank">[기획] 최초 한국 공연 &lt;식스 ...</a>
#  </li>
#  <li>
#  <a href="http://book.interpark.com/book/genbookeventaction.do?_method=EventPlan&amp;sc.evtNo=241721" target="_blank">[기획] 바야흐로 교양의 시대 4...</a>
#  </li>
#  </ul>
#  </div>
#  </div>
#  <!-- singleType or setType :: end -->
#  </li>]

# %%
li = lis[0]
li
# Out:
# <li>
# <!-- listItem | singleType or setType :: start -->
# <div class="listItem singleType">
# <div class="cover">
# <div class="coverImage">
# <label>
# <a href="/product/BookDisplay.do?_method=detail&amp;sc.shopNo=0000400000&amp;sc.prdNo=356522531&amp;sc.saNo=003003001&amp;bid1=Best_zone&amp;bid2=LiveRanking&amp;bid3=PRD&amp;bid4=001" target="_blank">
# <span class="checkBox">
# <input name="_KEY" type="checkbox" value="356522531"/>
# </span>
# <img alt="세이노의 가르침" src="http://bimage.interpark.com/goods_image/2/5/3/1/356522531s.jpg"/>
# <i class="decoFront"></i>
# </a>
# </label>
# </div>
# <div class="coverOption">
# <ul>
# <li class="cart">
# <a class="cartGo" href="#" value="356522531"><span>CART</span></a>
# </li>
# <li class="buy">
# <a href="javascript:directOrd('356522531');"><span>BUY</span></a>
# </li>
# </ul>
# </div>
# <div class="rankNumber digit2">
# <span class="rankBtn_ctrl rkNum_B01"></span>
# </div>
# </div>
# <div class="itemIcon">
# <span class="bestSeller">베스트셀러</span>
# </div>
# <a href="/product/BookDisplay.do?_method=detail&amp;sc.shopNo=0000400000&amp;sc.prdNo=356522531&amp;sc.saNo=003003001&amp;bid1=Best_zone&amp;bid2=LiveRanking&amp;bid3=PRD&amp;bid4=001" target="_blank">
# <div class="itemName"><strong>세이노의 가르침 </strong></div>
# <div class="itemMeta">
# <span class="author">세이노</span>
# <span class="company">데이원</span>
# </div>
# <div class="priceWrap">
# <span class="price">
# <em>6,480</em>
# <span class="currency">원</span>
# </span>
# <span class="benefits">
# <span>(</span>
# <span class="discount">
# <em>10%</em>
# <span class="unit">할인</span>
# </span>
# <span class="save">
# <em>5%</em>
# <span class="unit">적립</span>
# </span>
# <span>)</span>
# </span>
# </div>
# </a>
# <div class="reviewStat">
# <span class="title">평점</span>
# <span class="starRateWrap">
# <span class="starRate" style="width:99%">9.9</span>
# </span>
# <em class="rateNumber">9.9</em>
# </div>
# <div class="saleIndex">
# <span class="title">판매지수</span>
# <em class="indexNumber">256,409</em>
# </div>
# <div class="relatedEvent">
# <ul>
# <li>
# <a href="http://book.interpark.com/book/genbookeventaction.do?_method=EventPlan&amp;sc.evtNo=242222" target="_blank">[기획] 카카오페이와 도서상품권 ...</a>
# </li>
# <li>
# <a href="http://book.interpark.com/book/genbookeventaction.do?_method=EventPlan&amp;sc.evtNo=242643" target="_blank">[기획] 최초 한국 공연 &lt;식스 ...</a>
# </li>
# <li>
# <a href="http://book.interpark.com/book/genbookeventaction.do?_method=EventPlan&amp;sc.evtNo=242639" target="_blank">[기획] 카카오페이 &amp; 도서상품권...</a>
# </li>
# </ul>
# </div>
# </div>
# <!-- singleType or setType :: end -->
# </li>

# %% [markdown]
# - rank
#     - rankBtn_ctrl rkNum_B01 (1 ~ 9위)

# %%
lis[0].select('.rankBtn_ctrl')
# Out:
# [<span class="rankBtn_ctrl rkNum_B01"></span>]

# %%
lis[12].select('.rankBtn_ctrl')
# Out:
# [<span class="rankBtn_ctrl rkNum_B09"></span>]

# %%
' '.join(lis[0].select_one('.rankBtn_ctrl')['class'])
# Out:
# 'rankBtn_ctrl rkNum_B01'

# %%
# 순위
rank_data = lis[12].select('.rankBtn_ctrl')
if len(rank_data) == 1:
    rank = int(rank_data[0]['class'][-1][-1])
    print(rank)
else:
    rank = int(rank_data[0]['class'][-1][-1] + rank_data[1]['class'][-1][-1])
    print(rank)
# Out:
# 9

# %%
# 제목
title = li.select_one('.itemName').get_text().strip()
title
# Out:
# '세이노의 가르침'

# %%
# 저자
author = li.select_one('.author').get_text().strip()
author
# Out:
# '세이노'

# %%
# 출판사
company = li.select_one('.company').get_text().strip()
company
# Out:
# '데이원'

# %%
# 가격
price = li.select_one('.price > em' ).get_text().strip()
price = int(price.replace(',', ''))
price
# Out:
# 15480

# %%
# Out:
# 'http://bimage.interpark.com/renewPark/reBookpark/rankChart2016/text/h1_bestSeller.png'

# %% [markdown]
# #### 4. 데이터 반복문 처리

# %%
lines = []
for li in lis:
    rank_data = li.select('.rankBtn_ctrl')
    if len(rank_data) == 1:
        rank = int(rank_data[0]['class'][-1][-1])
    else:
        rank = int(rank_data[0]['class'][-1][-1] + rank_data[1]['class'][-1][-1])
        
    title = li.select_one('.itemName').get_text().strip()
    author = li.select_one('.author').get_text().strip()
    company = li.select_one('.company').get_text().strip()
    price = li.select_one('.price > em' ).get_text().strip()
    lines.append({'title': title, 'author': author, 'company':company, 'price':price, 'rank':rank})
lines
# Out:
# [{'title': '세이노의 가르침',
#   'author': '세이노',
#   'company': '데이원',
#   'price': '6,480',
#   'rank': 1},
#  {'title': '모든 삶은 흐른다',
#   'author': '로랑스 드빌레르/이주영 역',
#   'company': '피카(FIKA)',
#   'price': '15,120',
#   'rank': 2},
#  {'title': '사장학개론',
#   'author': '김승호',
#   'company': '스노우폭스북스',
#   'price': '22,500',
#   'rank': 3},
#  {'title': '건강과 다이어트를 동시에 잡는 7대 3의 법칙 채소·과일식',
#   'author': '조승우',
#   'company': '바이북스',
#   'price': '17,100',
#   'rank': 4},
#  {'title': '흔한남매 13',
#   'author': '흔한남매, 백난도/유난희 그림/흔한컴퍼니 감수',
#   'company': '미래엔아이세움',
#   'price': '13,050',
#   'rank': 5},
#  {'title': '장하준의 경제학 레시피',
#   'author': '장하준',
#   'company': '부키',
#   'price': '16,200',
#   'rank': 5},
#  {'title': '고래',
#   'author': '천명관',
#   'company': '문학동네',
#   'price': '13,500',
#   'rank': 5},
#  {'title': '부자 아빠 가난한 아빠 1(20주년 특별 기념판)',
#   'author': '로버트 기요사키/안진환 역',
#   'company': '민음인',
#   'price': '15,300',
#   'rank': 8},
#  {'title': '마법천자문 58: 온 정성과 힘을 다한다! 최선',
#   'author': '유대영/정수영 그림/강용철 감수',
#   'company': '아울북',
#   'price': '12,600',
#   'rank': 9},
#  {'title': '나의 돈 많은 고등학교 친구',
#   'author': '송희구',
#   'company': '서삼독',
#   'price': '16,200',
#   'rank': 9},
#  {'title': '요괴어사',
#   'author': '설민석, 원더스',
#   'company': '단꿈아이',
#   'price': '16,200',
#   'rank': 9},
#  {'title': '처음 배우는 주식 차트',
#   'author': '친절한 재승씨',
#   'company': '알에이치코리아',
#   'price': '34,200',
#   'rank': 9},
#  {'title': '호퍼 A-Z',
#   'author': '얼프 퀴스터/박상미 역',
#   'company': '한길사',
#   'price': '19,800',
#   'rank': 9},
#  {'title': '비트코인, 그리고 달러의 지정학',
#   'author': '오태민',
#   'company': '거인의정원',
#   'price': '49,500',
#   'rank': 9},
#  {'title': '만일 내가 인생을 다시 산다면(30만 부 기념 리커버 에디션)',
#   'author': '김혜남',
#   'company': '메이븐',
#   'price': '15,480',
#   'rank': 9}]

# %%
df = pd.DataFrame(lines)
df
# Out:
#                                  title                     author   company  \
# 0                             세이노의 가르침                        세이노       데이원
# 1                            모든 삶은 흐른다             로랑스 드빌레르/이주영 역  피카(FIKA)
# 2                                사장학개론                        김승호   스노우폭스북스
# 3     건강과 다이어트를 동시에 잡는 7대 3의 법칙 채소·과일식                        조승우      바이북스
# 4                              흔한남매 13  흔한남매, 백난도/유난희 그림/흔한컴퍼니 감수   미래엔아이세움
# 5                         장하준의 경제학 레시피                        장하준        부키
# 6                                   고래                        천명관      문학동네
# 7          부자 아빠 가난한 아빠 1(20주년 특별 기념판)             로버트 기요사키/안진환 역       민음인
# 8           마법천자문 58: 온 정성과 힘을 다한다! 최선          유대영/정수영 그림/강용철 감수       아울북
# 9                      나의 돈 많은 고등학교 친구                        송희구       서삼독
# 10                                요괴어사                   설민석, 원더스      단꿈아이
# 11                        처음 배우는 주식 차트                    친절한 재승씨   알에이치코리아
# 12                              호퍼 A-Z               얼프 퀴스터/박상미 역       한길사
# 13                   비트코인, 그리고 달러의 지정학                        오태민     거인의정원
# 14  만일 내가 인생을 다시 산다면(30만 부 기념 리커버 에디션)                        김혜남       메이븐
#
#      price  rank
# 0    6,480     1
# 1   15,120     2
# 2   22,500     3
# 3   17,100     4
# 4   13,050     5
# 5   16,200     5
# 6   13,500     5
# 7   15,300     8
# 8   12,600     9
# 9   16,200     9
# 10  16,200     9
# 11  34,200     9
# 12  19,800     9
# 13  49,500     9
# 14  15,480     9
