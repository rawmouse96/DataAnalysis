# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import img_util as iu

# %%
img = Image.open('static/img/moon.jpg')
plt.imshow(img)

# %%
h, w, _ = np.array(img).shape

# %%
if h > w:
    width, height = w, w
else : 
    width, height = h, h

# %%
diff = abs(h-w) // 2

# %%
if w > h:
    final_img = np.array(img)[:,diff:diff+h]
else:
    final_img = np.array(img)[diff:diff+w, :]

# %%
plt.imshow(final_img)

# %%
plt.imshow(np.array(img)[:200, 100:])

# %%
import img_util as iu

# %%
plt.imshow(iu.center_img(img))
