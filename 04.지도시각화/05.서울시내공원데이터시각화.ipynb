# %% [markdown]
# ### 서울시내 공원 현황 데이터 시각화

# %%
import pandas as pd
import folium
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False

# %%
df = pd.read_csv('data/서울시공원현황.csv', encoding='euc-kr')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 132 entries, 0 to 131
# Data columns (total 20 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   연번            132 non-null    int64
#  1   공원명           132 non-null    object
#  2   공원개요          131 non-null    object
#  3   면적            129 non-null    object
#  4   개원일           122 non-null    object
#  5   주요시설          124 non-null    object
#  6   주요식물          88 non-null     object
#  7   안내도           102 non-null    object
#  8   오시는길          115 non-null    object
#  9   이용시참고사항       120 non-null    object
#  10  이미지           132 non-null    object
#  11  지역            131 non-null    object
#  12  공원주소          132 non-null    object
#  13  관리부서          132 non-null    object
#  14  전화번호          132 non-null    object
#  15  X좌표(GRS80TM)  122 non-null    float64
#  16  Y좌표(GRS80TM)  122 non-null    float64
#  17  X좌표(WGS84)    131 non-null    float64
#  18  Y좌표(WGS84)    131 non-null    float64
#  19  바로가기          18 non-null     object
# dtypes: float64(4), int64(1), object(15)
# memory usage: 20.8+ KB

# %%
df = df[['공원명', '면적', '공원주소', 'X좌표(WGS84)', 'Y좌표(WGS84)']]
df.dropna(subset=['면적', 'X좌표(WGS84)'],inplace=True)
df.head(4)
# Out:
#         공원명                                            면적  \
# 0  남산도시자연공원  2896887㎡ 임 야 : 2454140㎡ 녹지대 및 기타시설 : 442747㎡
# 1    길동생태공원                                        80683㎡
# 2     서울대공원                                     9132690m²
# 3       서울숲                                       480994㎡
#
#                            공원주소  X좌표(WGS84)  Y좌표(WGS84)
# 0        서울특별시 중구 삼일대로 231(예장동)  126.990377   37.550140
# 1  서울특별시 강동구 천호대로 1291(길동생태공원)   127.154779   37.540394
# 2            경기도 과천시 대공원광장로 102  127.019846   37.426449
# 3    서울특별시 성동구 뚝섬로 273 (성수동1가)   127.041798   37.543072

# %%
# 이상한 데이터 삭제
df.drop([6], inplace=True)

# %%
# 시작할 때 있는 '총' 지우기
df.면적 = df.면적.str.replace('총', '')

# %%
# 앞에 있는 숫자만 추출하기 - 구분자 ㎡, ㎥, m
# 구분자가 여러개인 경우 split()
import re
re.split('[,.]', 'a,b,c')
# Out:
# ['a', 'b', 'c']

# %% [markdown]
# - 면적 데이터 전처리

# %%
# df.면적 = df.면적.apply(lambda x: re.split('[㎡㎥m]', x)[0])
# df.면적 = df.면적.astype(float).astype(int)
df.면적 = df.면적.str.extract(r'(\d+)').astype(int)
df.head(5)
# Out:
#         공원명       면적                          공원주소  X좌표(WGS84)  Y좌표(WGS84)
# 0  남산도시자연공원  2896887        서울특별시 중구 삼일대로 231(예장동)  126.990377   37.550140
# 1    길동생태공원    80683  서울특별시 강동구 천호대로 1291(길동생태공원)   127.154779   37.540394
# 2     서울대공원  9132690            경기도 과천시 대공원광장로 102  127.019846   37.426449
# 3       서울숲   480994    서울특별시 성동구 뚝섬로 273 (성수동1가)   127.041798   37.543072
# 4     월드컵공원  2284085     서울특별시 마포구 하늘공원로 84(월드컵공원)  126.878907   37.571805

# %% [markdown]
# - 공원 크기에 따른 분류

# %%
# 기준: 소형 < 100000, 중형 < 1000000, else 대형
criteria = [0, 100000, 1000000, 100000000]
label = ['소형', '중형', '대형']            # 분류 기준
size_info = [3, 7, 15]                      # circle marker의 크기
df['분류'] = pd.cut(df.면적, criteria, labels=label)
df['size'] = pd.cut(df.면적, criteria, labels=size_info)
df
# Out:
#                  공원명       면적                           공원주소  X좌표(WGS84)  \
# 0           남산도시자연공원  2896887         서울특별시 중구 삼일대로 231(예장동)  126.990377
# 1             길동생태공원    80683   서울특별시 강동구 천호대로 1291(길동생태공원)   127.154779
# 2              서울대공원  9132690             경기도 과천시 대공원광장로 102  127.019846
# 3                서울숲   480994     서울특별시 성동구 뚝섬로 273 (성수동1가)   127.041798
# 4              월드컵공원  2284085      서울특별시 마포구 하늘공원로 84(월드컵공원)  126.878907
# ..               ...      ...                            ...         ...
# 126          서일대뒷산공원   631021              서울특별시 중랑구 면목동 산19  127.098782
# 127  용마도시자연공원(사가정공원)   109635            서울특별시 중랑구 면목7동 산50   127.095997
# 128           문화비축기지   140022               서울특별시 마포구 증산로 87  126.893246
# 129            경춘선숲길   211392                노원구 공릉2동 산 82-2  127.076482
# 130             율현공원   157535  서울특별시 강남구 율현동 밤고개로24길(율현동 56)  127.115594
#
#      Y좌표(WGS84)  분류 size
# 0     37.550140  대형   15
# 1     37.540394  소형    3
# 2     37.426449  대형   15
# 3     37.543072  중형    7
# 4     37.571805  대형   15
# ..          ...  ..  ...
# 126   37.587716  중형    7
# 127   37.579762  중형    7
# 128   37.571718  중형    7
# 129   37.627077  중형    7
# 130   37.472332  중형    7
#
# [128 rows x 7 columns]

# %%
df.to_csv('data/공원(preprocessed)', index=False)

# %%
park = folium.Map([37.55, 126.98], zoom_start=11)

for i in df.index:
    folium.CircleMarker(
        location=[df['Y좌표(WGS84)'][i], df['X좌표(WGS84)'][i]],
        radius=int(df['size'][i]),
        popup=folium.Popup(df.공원주소[i], max_width=200), fill=True, color='black',
        tooltip=df.공원명[i]
        ).add_to(park)
    
title_html = "<h3 align='center' style='font-size:20px'>서울 주요 공원</h3>"
park.get_root().html.add_child(folium.Element(title_html))
park
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0a10305b0007afb8f6c5101be0939d03 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;h3 align=&#x27;center&#x27; style=&#x27;font-size:20px&#x27;&gt;서울 주요 공원&lt;/h3&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0a10305b0007afb8f6c5101be0939d03&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0a10305b0007afb8f6c5101be0939d03 = L.map(
#                 &quot;map_0a10305b0007afb8f6c5101be0939d03&quot;,
#                 {
#                     center: [37.55, 126.98],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_72aba121369340f5b3995dca96f4b546 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0a10305b0007afb8f6c5101be0939d03);
#
#
#             var circle_marker_d856f57242aa87d213a4bc26f24f84d8 = L.circleMarker(
#                 [37.5501402, 126.9903773],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 15, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0a10305b0007afb8f6c5101be0939d03);
#
#
#         var popup_5f1eb4798950f902ca9ca6cedcebcc69 = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_626026cc37d23f1c8c7bd8681a731deb = $(`&lt;div id=&quot;html_626026cc37d23f1c8c7bd8681a731deb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서울특별시 중구 삼일대로 231(예장동)&lt;/div&gt;`)[0];
#                 popup_5f1eb4798950f902ca9ca6cedcebcc69.setContent(html_626026cc37d23f1c8c7bd8681a731deb);
#
#
#
#         circle_marker_d856f57242aa87d213a4bc26f24f84d8.bindPopup(popup_5f1eb4798950f902ca9ca6cedcebcc69)
#         ;
#
#
#
#
#             circle_marker_d856f57242aa87d213a4bc26f24f84d8.bindTooltip(
#                 `&lt;div&gt;
#                      남산도시자연공원
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_1075aa26c3c30585fa68f2615542d16b = L.circleMarker(
#                 [37.5403935, 127.1547791],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0a10305b0007afb8f6c5101be0939d03);
#
#
#         var popup_8abb4e5b42576341a082a63aa3b56624 = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_7937e6ffffefc3871b53b2e99e62f63f = $(`&lt;div id=&quot;html_7937e6ffffefc3871b53b2e99e62f63f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서울특별시 강동구 천호대로 1291(길동생태공원) &lt;/div&gt;`)[0];
#                 popup_8abb4e5b42576341a082a63aa3b56624.setContent(html_7937e6ffffefc3871b53b2e99e62f63f);
#
#
#
#         circle_marker_1075aa26c3c30585fa68f2615542d16b.bindPopup(popup_8abb4e5b42576341a082a63aa3b56624)
#         ;
#
#
#
#
#             circle_marker_1075aa26c3c30585fa68f2615542d16b.bindTooltip(
#                 `&lt;div&gt;
#                      길동생태공원
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_b0fc06d57f1cf532dd1ac8f1eb7ff30c = L.circleMarker(
#                 [37.4264494, 127.0198465],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 15, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0a10305b0007afb8f6c5101be0939d03);
#
#
#         var popup_ff36c7f74de4510f611d0af9b7dfc0ad = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_0e86e8463361d5400092b579a15e0add = $(`&lt;div id=&quot;html_0e86e8463361d5400092b579a15e0add&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;경기도 과천시 대공원광장로 102&lt;/div&gt;`)[0];
