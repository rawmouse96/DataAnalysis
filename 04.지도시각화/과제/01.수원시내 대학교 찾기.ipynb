# %% [markdown]
# ### 수원시내 대학교 찾기

# %%
import requests
from urllib.parse import quote
import pandas as pd
import folium
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False

# %%
# 카카오 인증키 불러오기
with open('../data/kakaoapikey.txt') as f:
    kakao_key = f.read()

# %%
# url list
addr_list = ['아주대학교', '동남보건대학', '수원 경기대학교', '수원 성균관대학교', '수원여자대학교', '용인 경희대학교']
base_url = 'https://dapi.kakao.com/v2/local/search/keyword.json'
url_list = []

for addr in addr_list:
    temp = f'{base_url}?query={quote(addr)}'
    url_list.append(temp)
url_list
# Out:
# ['https://dapi.kakao.com/v2/local/search/keyword.json?query=%EC%95%84%EC%A3%BC%EB%8C%80%ED%95%99%EA%B5%90',
#  'https://dapi.kakao.com/v2/local/search/keyword.json?query=%EB%8F%99%EB%82%A8%EB%B3%B4%EA%B1%B4%EB%8C%80%ED%95%99',
#  'https://dapi.kakao.com/v2/local/search/keyword.json?query=%EC%88%98%EC%9B%90%20%EA%B2%BD%EA%B8%B0%EB%8C%80%ED%95%99%EA%B5%90',
#  'https://dapi.kakao.com/v2/local/search/keyword.json?query=%EC%88%98%EC%9B%90%20%EC%84%B1%EA%B7%A0%EA%B4%80%EB%8C%80%ED%95%99%EA%B5%90',
#  'https://dapi.kakao.com/v2/local/search/keyword.json?query=%EC%88%98%EC%9B%90%EC%97%AC%EC%9E%90%EB%8C%80%ED%95%99%EA%B5%90',
#  'https://dapi.kakao.com/v2/local/search/keyword.json?query=%EC%9A%A9%EC%9D%B8%20%EA%B2%BD%ED%9D%AC%EB%8C%80%ED%95%99%EA%B5%90']

# %%
# result list
header = {"Authorization": f'KakaoAK {kakao_key}'}

result_list = []
for url in url_list:
    result_list.append(requests.get(url, headers=header).json())
result_list[0]
# Out:
# {'documents': [{'address_name': '경기 수원시 영통구 원천동 산 5-1',
#    'category_group_code': 'SC4',
#    'category_group_name': '학교',
#    'category_name': '교육,학문 > 학교 > 대학교',
#    'distance': '',
#    'id': '9894681',
#    'phone': '031-219-2114',
#    'place_name': '아주대학교',
#    'place_url': 'http://place.map.kakao.com/9894681',
#    'road_address_name': '경기 수원시 영통구 월드컵로 206',
#    'x': '127.04355285631813',
#    'y': '37.28295793156606'},
#   {'address_name': '경기 수원시 영통구 원천동 산 26-6',
#    'category_group_code': 'HP8',
#    'category_group_name': '병원',
#    'category_name': '의료,건강 > 병원 > 대학병원',
#    'distance': '',
#    'id': '10063656',
#    'phone': '1688-6114',
#    'place_name': '아주대학교병원',
#    'place_url': 'http://place.map.kakao.com/10063656',
#    'road_address_name': '경기 수원시 영통구 월드컵로 164',
#    'x': '127.04753911133689',
#    'y': '37.27944594804333'},
#   {'address_name': '경기 수원시 영통구 원천동 산 5-1',
#    'category_group_code': '',
#    'category_group_name': '',
#    'category_name': '가정,생활 > 장례 > 장례식장',
#    'distance': '',
#    'id': '17578912',
#    'phone': '031-219-6975',
#    'place_name': '아주대학교병원 장례식장',
#    'place_url': 'http://place.map.kakao.com/17578912',
#    'road_address_name': '경기 수원시 영통구 광교중앙로49번길 46',
#    'x': '127.04954720370763',
#    'y': '37.28094986073233'},
#   {'address_name': '경기 수원시 영통구 원천동 561',
#    'category_group_code': 'HP8',
#    'category_group_name': '병원',
#    'category_name': '의료,건강 > 병원 > 노인,요양병원',
#    'distance': '',
#    'id': '1224548234',
#    'phone': '031-5174-5000',
#    'place_name': '아주대학교요양병원',
#    'place_url': 'http://place.map.kakao.com/1224548234',
#    'road_address_name': '경기 수원시 영통구 월드컵로150번길 21',
#    'x': '127.04916834948963',
#    'y': '37.27925155900331'},
#   {'address_name': '경기 수원시 영통구 원천동 산 26-6',
#    'category_group_code': '',
#    'category_group_name': '',
#    'category_name': '의료,건강 > 의료단체',
#    'distance': '',
#    'id': '24529029',
#    'phone': '1688-6114',
#    'place_name': '아주대학교의료원',
#    'place_url': 'http://place.map.kakao.com/24529029',
#    'road_address_name': '경기 수원시 영통구 월드컵로 164',
#    'x': '127.04751994291286',
#    'y': '37.27944685677934'},
#   {'address_name': '경기 수원시 영통구 원천동 산 26-6',
#    'category_group_code': '',
#    'category_group_name': '',
#    'category_name': '의료,건강 > 병원부속시설',
#    'distance': '',
#    'id': '17572583',
#    'phone': '031-219-7115',
#    'place_name': '아주대학교병원 웰빙센터',
#    'place_url': 'http://place.map.kakao.com/17572583',
#    'road_address_name': '경기 수원시 영통구 월드컵로 164',
#    'x': '127.046302980492',
#    'y': '37.2789652827671'},
#   {'address_name': '경기 수원시 영통구 원천동 산 26-6',
#    'category_group_code': '',
#    'category_group_name': '',
#    'category_name': '의료,건강 > 병원 > 응급실',
#    'distance': '',
#    'id': '26945888',
#    'phone': '1688-6114',
#    'place_name': '아주대학교병원 경기남부권역 응급의료센터',
#    'place_url': 'http://place.map.kakao.com/26945888',
#    'road_address_name': '경기 수원시 영통구 월드컵로 164',
#    'x': '127.04828348610833',
#    'y': '37.279706948286005'},
#   {'address_name': '경기 수원시 영통구 원천동 1',
#    'category_group_code': '',
#    'category_group_name': '',
#    'category_name': '교통,수송 > 입출구',
#    'distance': '',
#    'id': '1685311884',
#    'phone': '',
#    'place_name': '아주대학교 정문',
#    'place_url': 'http://place.map.kakao.com/1685311884',
#    'road_address_name': '',
#    'x': '127.04366058847707',
#    'y': '37.280103398975044'},
#   {'address_name': '경기 수원시 영통구 원천동 산 26-6',
#    'category_group_code': '',
#    'category_group_name': '',
#    'category_name': '금융,보험 > 금융서비스 > 협동,소비조합 > 신용협동조합',
#    'distance': '',
#    'id': '20884710',
#    'phone': '031-219-6052',
#    'place_name': '아주대학교의료원신협 본점',
#    'place_url': 'http://place.map.kakao.com/20884710',
#    'road_address_name': '경기 수원시 영통구 월드컵로 164',
#    'x': '127.04761136208',
#    'y': '37.2795810749644'},
#   {'address_name': '경기 수원시 영통구 원천동 산 5-1',
#    'category_group_code': '',
#    'category_group_name': '',
#    'category_name': '스포츠,레저 > 스포츠시설 > 체육관',
#    'distance': '',
#    'id': '17574283',
#    'phone': '031-219-1661',
#    'place_name': '아주대학교 체육관',
#    'place_url': 'http://place.map.kakao.com/17574283',
#    'road_address_name': '경기 수원시 영통구 월드컵로 206',
#    'x': '127.04546805034515',
#    'y': '37.279974770904936'},
#   {'address_name': '경기 수원시 영통구 원천동 1',
#    'category_group_code': '',
#    'category_group_name': '',
#    'category_name': '교육,학문 > 학교부속시설',
#    'distance': '',
#    'id': '1299715407',
#    'phone': '',
#    'place_name': '아주대학교 연암관',
#    'place_url': 'http://place.map.kakao.com/1299715407',
#    'road_address_name': '경기 수원시 영통구 월드컵로 206',
#    'x': '127.04754085740042',
#    'y': '37.28222205010366'},
#   {'address_name': '경기 수원시 영통구 원천동 산 5-1',
#    'category_group_code': '',
#    'category_group_name': '',
#    'category_name': '부동산 > 주거시설 > 기숙사,기숙시설',
#    'distance': '',
#    'id': '506590262',
#    'phone': '',
#    'place_name': '아주대학교 일신관',
#    'place_url': 'http://place.map.kakao.com/506590262',
#    'road_address_name': '경기 수원시 영통구 월드컵로 206',
#    'x': '127.04705730591631',
#    'y': '37.284356805056845'},
#   {'address_name': '경기 수원시 영통구 원천동 1',
#    'category_group_code': '',
#    'category_group_name': '',
#    'category_name': '교통,수송 > 입출구',
#    'distance': '',
#    'id': '27597083',
#    'phone': '',
#    'place_name': '아주대학교 병원정문',
#    'place_url': 'http://place.map.kakao.com/27597083',
#    'road_address_name': '경기 수원시 영통구 월드컵로 164',
#    'x': '127.047547285285',
#    'y': '37.2780997912476'},
#   {'address_name': '경기 수원시 영통구 원천동 1',
#    'category_group_code': '',
#    'category_group_name': '',
#    'category_name': '교육,학문 > 학교부속시설',
#    'distance': '',
#    'id': '17564486',
#    'phone': '031-219-3621',
#    'place_name': '아주대학교 다산관',
#    'place_url': 'http://place.map.kakao.com/17564486',
#    'road_address_name': '경기 수원시 영통구 월드컵로 206',
#    'x': '127.047739844294',
#    'y': '37.2830518271645'},
#   {'address_name': '경기 수원시 영통구 원천동 산 5-1',
#    'category_group_code': '',
#    'category_group_name': '',
#    'category_name': '사회,공공기관 > 행정기관 > 과학기술정보통신부 > 우체국 > 우편취급국',
#    'distance': '',
#    'id': '7989012',
#    'phone': '031-219-2275',
#    'place_name': '수원아주대학교우편취급국',
#    'place_url': 'http://place.map.kakao.com/7989012',
#    'road_address_name': '경기 수원시 영통구 월드컵로 206',
#    'x': '127.04521424645759',
#    'y': '37.28358623396756'}],
#  'meta': {'is_end': False,
#   'pageable_count': 45,
#   'same_name': {'keyword': '아주대학교', 'region': [], 'selected_region': ''},
#   'total_count': 581}}

# %%
# information in result
univ_addr = []
lat = []
lon = []
for result in result_list:
    univ_addr.append(result['documents'][0]['road_address_name'])
    lat.append(float(result['documents'][0]['y'])),
    lon.append(float(result['documents'][0]['x']))
    
df = pd.DataFrame({
        '대학교명' : addr_list,
        '주소' : univ_addr,
        '위도' : lat,
        '경도' : lon
    })
df['color'] = ['red', 'green', 'blue', 'orange', 'black', 'purple']
df
# Out:
#         대학교명                      주소         위도          경도   color
# 0      아주대학교     경기 수원시 영통구 월드컵로 206  37.282958  127.043553     red
# 1     동남보건대학   경기 수원시 장안구 천천로74번길 50  37.297891  126.987917   green
# 2   수원 경기대학교  경기 수원시 영통구 광교산로 154-42  37.301149  127.035141    blue
# 3  수원 성균관대학교     경기 수원시 장안구 서부로 2066  37.295041  126.977421  orange
# 4    수원여자대학교       경기 수원시 권선구 온정로 72  37.252449  126.964026   black
# 5   용인 경희대학교    경기 용인시 기흥구 덕영대로 1732  37.242910  127.081190  purple

# %%
map = folium.Map(location=[df['위도'].mean(), df['경도'].mean()], zoom_start=13)

for i in df.index:
    folium.Marker(
    location=[df.위도[i],df.경도[i]],          # WGS84 좌표계, (latitude,longtitude)
    popup=folium.Popup(df.주소[i], max_width=200),
    icon=folium.Icon(color=df.color[i], icon='star'),
    tooltip=df.대학교명[i]
    ).add_to(map)

title_html = "<h3 align='center' style='font-size:20px'>수원 소재 대학교</h3>"
map.get_root().html.add_child(folium.Element(title_html))
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2b55cba788d9564e6eb2de12ac5a4871 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;h3 align=&#x27;center&#x27; style=&#x27;font-size:20px&#x27;&gt;수원 소재 대학교&lt;/h3&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2b55cba788d9564e6eb2de12ac5a4871&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2b55cba788d9564e6eb2de12ac5a4871 = L.map(
#                 &quot;map_2b55cba788d9564e6eb2de12ac5a4871&quot;,
#                 {
#                     center: [37.27873315927908, 127.0148746894056],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_161b9c7b1a45c20dc8668c8bcd406bdd = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_2b55cba788d9564e6eb2de12ac5a4871);
#
#
#             var marker_48eb7a1d82141980625238cba5a7fcdc = L.marker(
#                 [37.28295793156606, 127.04355285631813],
#                 {}
#             ).addTo(map_2b55cba788d9564e6eb2de12ac5a4871);
#
#
#             var icon_64653e71f24244a0d3a91d836b58b1f4 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_48eb7a1d82141980625238cba5a7fcdc.setIcon(icon_64653e71f24244a0d3a91d836b58b1f4);
#
#
#         var popup_c77b4b67d9ccce314ed42d5d054f975f = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_bb416fa17942e61b07f8c39cd0c0deaf = $(`&lt;div id=&quot;html_bb416fa17942e61b07f8c39cd0c0deaf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;경기 수원시 영통구 월드컵로 206&lt;/div&gt;`)[0];
#                 popup_c77b4b67d9ccce314ed42d5d054f975f.setContent(html_bb416fa17942e61b07f8c39cd0c0deaf);
#
#
#
#         marker_48eb7a1d82141980625238cba5a7fcdc.bindPopup(popup_c77b4b67d9ccce314ed42d5d054f975f)
#         ;
#
#
#
#
#             marker_48eb7a1d82141980625238cba5a7fcdc.bindTooltip(
#                 `&lt;div&gt;
#                      아주대학교
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_c4cab6bdb42fc9ac6c0b306ffaf9af40 = L.marker(
#                 [37.29789102372988, 126.98791720002457],
#                 {}
#             ).addTo(map_2b55cba788d9564e6eb2de12ac5a4871);
#
#
#             var icon_a9f7ea6926058ed637b9ec75d74843dc = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c4cab6bdb42fc9ac6c0b306ffaf9af40.setIcon(icon_a9f7ea6926058ed637b9ec75d74843dc);
#
#
#         var popup_dcf2310bb3701baddfd2141fd98e97f3 = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_141a5da3d67c17b1f51566aeab0a1941 = $(`&lt;div id=&quot;html_141a5da3d67c17b1f51566aeab0a1941&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;경기 수원시 장안구 천천로74번길 50&lt;/div&gt;`)[0];
#                 popup_dcf2310bb3701baddfd2141fd98e97f3.setContent(html_141a5da3d67c17b1f51566aeab0a1941);
#
#
#
#         marker_c4cab6bdb42fc9ac6c0b306ffaf9af40.bindPopup(popup_dcf2310bb3701baddfd2141fd98e97f3)
#         ;
#
#
#
#
#             marker_c4cab6bdb42fc9ac6c0b306ffaf9af40.bindTooltip(
#                 `&lt;div&gt;
#                      동남보건대학
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_5f6864f0e309fae9565c4ef3d332801d = L.marker(
#                 [37.30114907752158, 127.03514122548546],
#                 {}
#             ).addTo(map_2b55cba788d9564e6eb2de12ac5a4871);
#
#
#             var icon_3507a0db8fff988305a1602b50cf86f3 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_5f6864f0e309fae9565c4ef3d332801d.setIcon(icon_3507a0db8fff988305a1602b50cf86f3);
#
#
#         var popup_0ed0fa3ce7840ce2d403802a5a545f28 = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_50ec3ef31d6b60033c95058b8ce7c46f = $(`&lt;div id=&quot;html_50ec3ef31d6b60033c95058b8ce7c46f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;경기 수원시 영통구 광교산로 154-42&lt;/div&gt;`)[0];
#                 popup_0ed0fa3ce7840ce2d403802a5a54
